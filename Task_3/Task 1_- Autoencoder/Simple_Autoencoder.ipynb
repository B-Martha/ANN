# %% [markdown]
# # A Simple Autoencoder
#
# We'll start off by building a simple autoencoder to compress the MNIST dataset. With autoencoders, we pass input data through an encoder that makes a compressed representation of the input. Then, this representation is passed through a decoder to reconstruct the input data. Generally the encoder and decoder will be built with neural networks, then trained on example data.
#
# ![Autoencoder](assets/autoencoder_1.png)
#
# In this notebook, we'll be build a simple network architecture for the encoder and decoder. Let's get started by importing our libraries and getting the dataset.

# %%
# %matplotlib inline
# %tensorflow_version 1.x
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# TensorFlow 1.x selected.

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', validation_size=0)
# mnist = tf.keras.datasets.mnist
# Out:
# WARNING:tensorflow:From <ipython-input-2-8775f426cfc8>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# Below I'm plotting an example image from the MNIST dataset. These are 28x28 grayscale images of handwritten digits.

# %%
img = mnist.train.images[2]
plt.imshow(img.reshape((28, 28)), cmap='Greys_r')
img_size = mnist.train.images.shape[1]
# batch_size = 200
# batch = mnist.train.next_batch(batch_size)
# for x in batch:
#   print(x)

# %% [markdown]
# We'll train an autoencoder with these images by flattening them into 784 length vectors. The images from this dataset are already normalized such that the values are between 0 and 1. Let's start by building basically the simplest autoencoder with a **single ReLU hidden layer**. This layer will be used as the compressed representation. Then, the encoder is the input layer and the hidden layer. The decoder is the hidden layer and the output layer. Since the images are normalized between 0 and 1, we need to use a **sigmoid activation on the output layer** to get values matching the input.
#
# ![Autoencoder architecture](assets/simple_autoencoder.png)
#
#
# > **Exercise:** Build the graph for the autoencoder in the cell below. The input images will be flattened into 784 length vectors. The targets are the same as the inputs. And there should be one hidden layer with a ReLU activation and an output layer with a sigmoid activation. Feel free to use TensorFlow's higher level API, `tf.layers`. For instance, you would use [`tf.layers.dense(inputs, units, activation=tf.nn.relu)`](https://www.tensorflow.org/api_docs/python/tf/layers/dense) to create a fully connected layer with a ReLU activation. The loss should be calculated with the cross-entropy loss, there is a convenient TensorFlow function for this `tf.nn.sigmoid_cross_entropy_with_logits` ([documentation](https://www.tensorflow.org/api_docs/python/tf/nn/sigmoid_cross_entropy_with_logits)). You should note that `tf.nn.sigmoid_cross_entropy_with_logits` takes the logits, but to get the reconstructed images you'll need to pass the logits through the sigmoid function.

# %%
# Size of the encoding layer (the hidden layer)
encoding_dim = 32 # feel free to change this value

# Input and target placeholders
inputs_ = tf.placeholder(tf.float32, shape = (None, img_size), name = "inputs")
targets_ = tf.placeholder(tf.float32, shape = (None, img_size), name = "targets")

# Output of hidden layer, single fully connected layer here with ReLU activation
encoded = tf.layers.dense(inputs_, encoding_dim, activation=tf.nn.relu, name = "hidden")

# Output layer logits, fully connected layer with no activation
logits = tf.layers.dense(encoded, img_size, activation=None)
# Sigmoid output from logits
decoded = tf.sigmoid(logits)

# Sigmoid cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(logits = logits, labels = targets_)
# Mean of the loss
cost = tf.reduce_mean(loss)

# Adam optimizer
opt = tf.train.AdamOptimizer(learning_rate=0.001).minimize(cost)
# Out:
# WARNING:tensorflow:From <ipython-input-4-92f413453283>:9: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ## Training

# %%
# Create the session
sess = tf.Session()

# %% [markdown]
# Here I'll write a bit of code to train the network. I'm not too interested in validation here, so I'll just monitor the training loss.
#
# Calling `mnist.train.next_batch(batch_size)` will return a tuple of `(images, labels)`. We're not concerned with the labels here, we just need the images. Otherwise this is pretty straightfoward training with TensorFlow. We initialize the variables with `sess.run(tf.global_variables_initializer())`. Then, run the optimizer and get the loss with `batch_cost, _ = sess.run([cost, opt], feed_dict=feed)`.

# %%
epochs = 2
batch_size = 200
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        feed = {inputs_: batch[0], targets_: batch[0]}
        batch_cost, _ = sess.run([cost, opt], feed_dict=feed)

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epoch: 1/2... Training loss: 0.6931
# Epoch: 1/2... Training loss: 0.6900
# Epoch: 1/2... Training loss: 0.6869
# Epoch: 1/2... Training loss: 0.6824
# Epoch: 1/2... Training loss: 0.6778
# Epoch: 1/2... Training loss: 0.6719
# Epoch: 1/2... Training loss: 0.6650
# Epoch: 1/2... Training loss: 0.6572
# Epoch: 1/2... Training loss: 0.6476
# Epoch: 1/2... Training loss: 0.6375
# Epoch: 1/2... Training loss: 0.6255
# Epoch: 1/2... Training loss: 0.6111
# Epoch: 1/2... Training loss: 0.5958
# Epoch: 1/2... Training loss: 0.5828
# Epoch: 1/2... Training loss: 0.5664
# Epoch: 1/2... Training loss: 0.5495
# Epoch: 1/2... Training loss: 0.5372
# Epoch: 1/2... Training loss: 0.5139
# Epoch: 1/2... Training loss: 0.4972
# Epoch: 1/2... Training loss: 0.4783
# Epoch: 1/2... Training loss: 0.4629
# Epoch: 1/2... Training loss: 0.4475
# Epoch: 1/2... Training loss: 0.4303
# Epoch: 1/2... Training loss: 0.4174
# Epoch: 1/2... Training loss: 0.3983
# Epoch: 1/2... Training loss: 0.3902
# Epoch: 1/2... Training loss: 0.3702
# Epoch: 1/2... Training loss: 0.3623
# Epoch: 1/2... Training loss: 0.3577
# Epoch: 1/2... Training loss: 0.3465
# Epoch: 1/2... Training loss: 0.3354
# Epoch: 1/2... Training loss: 0.3287
# Epoch: 1/2... Training loss: 0.3209
# Epoch: 1/2... Training loss: 0.3182
# Epoch: 1/2... Training loss: 0.3179
# Epoch: 1/2... Training loss: 0.3053
# Epoch: 1/2... Training loss: 0.3119
# Epoch: 1/2... Training loss: 0.3043
# Epoch: 1/2... Training loss: 0.3033
# Epoch: 1/2... Training loss: 0.2930
# Epoch: 1/2... Training loss: 0.2988
# Epoch: 1/2... Training loss: 0.2908
# Epoch: 1/2... Training loss: 0.2950
# Epoch: 1/2... Training loss: 0.2851
# Epoch: 1/2... Training loss: 0.2927
# Epoch: 1/2... Training loss: 0.2865
# Epoch: 1/2... Training loss: 0.2858
# Epoch: 1/2... Training loss: 0.2847
# Epoch: 1/2... Training loss: 0.2849
# Epoch: 1/2... Training loss: 0.2877
# Epoch: 1/2... Training loss: 0.2850
# Epoch: 1/2... Training loss: 0.2792
# Epoch: 2/2... Training loss: 0.1629
# Epoch: 2/2... Training loss: 0.1637
# Epoch: 2/2... Training loss: 0.1650
# Epoch: 2/2... Training loss: 0.1650
# Epoch: 2/2... Training loss: 0.1657
# Epoch: 2/2... Training loss: 0.1618
# Epoch: 2/2... Training loss: 0.1638
# Epoch: 2/2... Training loss: 0.1680
# Epoch: 2/2... Training loss: 0.1663
# Epoch: 2/2... Training loss: 0.1685
# Epoch: 2/2... Training loss: 0.1711
# Epoch: 2/2... Training loss: 0.1605
# Epoch: 2/2... Training loss: 0.1632
# Epoch: 2/2... Training loss: 0.1615
# Epoch: 2/2... Training loss: 0.1586
# Epoch: 2/2... Training loss: 0.1659
# Epoch: 2/2... Training loss: 0.1561
# Epoch: 2/2... Training loss: 0.1698
# Epoch: 2/2... Training loss: 0.1680
# Epoch: 2/2... Training loss: 0.1637
# Epoch: 2/2... Training loss: 0.1652
# Epoch: 2/2... Training loss: 0.1606
# Epoch: 2/2... Training loss: 0.1661
# Epoch: 2/2... Training loss: 0.1633
# Epoch: 2/2... Training loss: 0.1614
# Epoch: 2/2... Training loss: 0.1585
# Epoch: 2/2... Training loss: 0.1561
# Epoch: 2/2... Training loss: 0.1669
# Epoch: 2/2... Training loss: 0.1594
# Epoch: 2/2... Training loss: 0.1622
# Epoch: 2/2... Training loss: 0.1626
# Epoch: 2/2... Training loss: 0.1682
# Epoch: 2/2... Training loss: 0.1618
# Epoch: 2/2... Training loss: 0.1649
# Epoch: 2/2... Training loss: 0.1565
# Epoch: 2/2... Training loss: 0.1576
# Epoch: 2/2... Training loss: 0.1611
# Epoch: 2/2... Training loss: 0.1606
# Epoch: 2/2... Training loss: 0.1587
# Epoch: 2/2... Training loss: 0.1613
# Epoch: 2/2... Training loss: 0.1581
# Epoch: 2/2... Training loss: 0.1644
# Epoch: 2/2... Training loss: 0.1627
# Epoch: 2/2... Training loss: 0.1620
# Epoch: 2/2... Training loss: 0.1600
# Epoch: 2/2... Training loss: 0.1649
# Epoch: 2/2... Training loss: 0.1592
# Epoch: 2/2... Training loss: 0.1612
# Epoch: 2/2... Training loss: 0.1575
# Epoch: 2/2... Training loss: 0.1605
# Epoch: 2/2... Training loss: 0.1653
# Epoch: 2/2... Training loss: 0.1525
# Epoch: 2/2... Training loss: 0.1517
# Epoch: 2/2... Training loss: 0.1564
# Epoch: 2/2... Training loss: 0.1594
# Epoch: 2/2... Training loss: 0.1567
# Epoch: 2/2... Training loss: 0.1688
# Epoch: 2/2... Training loss: 0.1547
# Epoch: 2/2... Training loss: 0.1560
# Epoch: 2/2... Training loss: 0.1551
# Epoch: 2/2... Training loss: 0.1599
# Epoch: 2/2... Training loss: 0.1555
# Epoch: 2/2... Training loss: 0.1569
# Epoch: 2/2... Training loss: 0.1560
# Epoch: 2/2... Training loss: 0.1563
# Epoch: 2/2... Training loss: 0.1589
# Epoch: 2/2... Training loss: 0.1596
# Epoch: 2/2... Training loss: 0.1583
# Epoch: 2/2... Training loss: 0.1574
# Epoch: 2/2... Training loss: 0.1597
# Epoch: 2/2... Training loss: 0.1598
# Epoch: 2/2... Training loss: 0.1568
# Epoch: 2/2... Training loss: 0.1572
# Epoch: 2/2... Training loss: 0.1579
# Epoch: 2/2... Training loss: 0.1498
# Epoch: 2/2... Training loss: 0.1578
# Epoch: 2/2... Training loss: 0.1602
# Epoch: 2/2... Training loss: 0.1562
# Epoch: 2/2... Training loss: 0.1566
# Epoch: 2/2... Training loss: 0.1550
# Epoch: 2/2... Training loss: 0.1558
# Epoch: 2/2... Training loss: 0.1579
# Epoch: 2/2... Training loss: 0.1580
# Epoch: 2/2... Training loss: 0.1574
# Epoch: 2/2... Training loss: 0.1586
# Epoch: 2/2... Training loss: 0.1519
# Epoch: 2/2... Training loss: 0.1517
# Epoch: 2/2... Training loss: 0.1497
# Epoch: 2/2... Training loss: 0.1556
# Epoch: 2/2... Training loss: 0.1518
# Epoch: 2/2... Training loss: 0.1572
# Epoch: 2/2... Training loss: 0.1545
# Epoch: 2/2... Training loss: 0.1510
# Epoch: 2/2... Training loss: 0.1517
# Epoch: 2/2... Training loss: 0.1530
# Epoch: 2/2... Training loss: 0.1565
# Epoch: 2/2... Training loss: 0.1601
# Epoch: 2/2... Training loss: 0.1587
# Epoch: 2/2... Training loss: 0.1499
# Epoch: 2/2... Training loss: 0.1505
# Epoch: 2/2... Training loss: 0.1566
# Epoch: 2/2... Training loss: 0.1576
# Epoch: 2/2... Training loss: 0.1561
# Epoch: 2/2... Training loss: 0.1553
# Epoch: 2/2... Training loss: 0.1556
# Epoch: 2/2... Training loss: 0.1494
# Epoch: 2/2... Training loss: 0.1476
# Epoch: 2/2... Training loss: 0.1502
# Epoch: 2/2... Training loss: 0.1482
# Epoch: 2/2... Training loss: 0.1485
# Epoch: 2/2... Training loss: 0.1612
# Epoch: 2/2... Training loss: 0.1514
# Epoch: 2/2... Training loss: 0.1566
# Epoch: 2/2... Training loss: 0.1568
# Epoch: 2/2... Training loss: 0.1512
# Epoch: 2/2... Training loss: 0.1472
# Epoch: 2/2... Training loss: 0.1446
# Epoch: 2/2... Training loss: 0.1525
# Epoch: 2/2... Training loss: 0.1525
# Epoch: 2/2... Training loss: 0.1548
# Epoch: 2/2... Training loss: 0.1466
# Epoch: 2/2... Training loss: 0.1527
# Epoch: 2/2... Training loss: 0.1501
# Epoch: 2/2... Training loss: 0.1502
# Epoch: 2/2... Training loss: 0.1486
# Epoch: 2/2... Training loss: 0.1520
# Epoch: 2/2... Training loss: 0.1503
# Epoch: 2/2... Training loss: 0.1547
# Epoch: 2/2... Training loss: 0.1529
# Epoch: 2/2... Training loss: 0.1518
# Epoch: 2/2... Training loss: 0.1517
# Epoch: 2/2... Training loss: 0.1541
# Epoch: 2/2... Training loss: 0.1488
# Epoch: 2/2... Training loss: 0.1511
# Epoch: 2/2... Training loss: 0.1523
# Epoch: 2/2... Training loss: 0.1526
# Epoch: 2/2... Training loss: 0.1474
# Epoch: 2/2... Training loss: 0.1489
# Epoch: 2/2... Training loss: 0.1477
# Epoch: 2/2... Training loss: 0.1484
# Epoch: 2/2... Training loss: 0.1484
# Epoch: 2/2... Training loss: 0.1527
# Epoch: 2/2... Training loss: 0.1523
# Epoch: 2/2... Training loss: 0.1458
# Epoch: 2/2... Training loss: 0.1585
# Epoch: 2/2... Training loss: 0.1459
# Epoch: 2/2... Training loss: 0.1531
# Epoch: 2/2... Training loss: 0.1538
# Epoch: 2/2... Training loss: 0.1557
# Epoch: 2/2... Training loss: 0.1477
# Epoch: 2/2... Training loss: 0.1444
# Epoch: 2/2... Training loss: 0.1527
# Epoch: 2/2... Training loss: 0.1568
# Epoch: 2/2... Training loss: 0.1471
# Epoch: 2/2... Training loss: 0.1489
# Epoch: 2/2... Training loss: 0.1470
# Epoch: 2/2... Training loss: 0.1476
# Epoch: 2/2... Training loss: 0.1489
# Epoch: 2/2... Training loss: 0.1505
# Epoch: 2/2... Training loss: 0.1491
# Epoch: 2/2... Training loss: 0.1448
# Epoch: 2/2... Training loss: 0.1474
# Epoch: 2/2... Training loss: 0.1501
# Epoch: 2/2... Training loss: 0.1490
# Epoch: 2/2... Training loss: 0.1460
# Epoch: 2/2... Training loss: 0.1457
# Epoch: 2/2... Training loss: 0.1511
# Epoch: 2/2... Training loss: 0.1480
# Epoch: 2/2... Training loss: 0.1446
# Epoch: 2/2... Training loss: 0.1443
# Epoch: 2/2... Training loss: 0.1483
# Epoch: 2/2... Training loss: 0.1464
# Epoch: 2/2... Training loss: 0.1519
# Epoch: 2/2... Training loss: 0.1457
# Epoch: 2/2... Training loss: 0.1484
# Epoch: 2/2... Training loss: 0.1395
# Epoch: 2/2... Training loss: 0.1422
# Epoch: 2/2... Training loss: 0.1440
# Epoch: 2/2... Training loss: 0.1488
# Epoch: 2/2... Training loss: 0.1474
# Epoch: 2/2... Training loss: 0.1461
# Epoch: 2/2... Training loss: 0.1511
# Epoch: 2/2... Training loss: 0.1473
# Epoch: 2/2... Training loss: 0.1467
# Epoch: 2/2... Training loss: 0.1442
# Epoch: 2/2... Training loss: 0.1454
# Epoch: 2/2... Training loss: 0.1428
# Epoch: 2/2... Training loss: 0.1472
# Epoch: 2/2... Training loss: 0.1474
# Epoch: 2/2... Training loss: 0.1421
# Epoch: 2/2... Training loss: 0.1416
# Epoch: 2/2... Training loss: 0.1489
# Epoch: 2/2... Training loss: 0.1469
# Epoch: 2/2... Training loss: 0.1471

# %% [markdown]
# ## Checking out the results
#
# Below I've plotted some of the test images along with their reconstructions. For the most part these look pretty good except for some blurriness in some parts.

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
reconstructed, compressed = sess.run([decoded, encoded], feed_dict={inputs_: in_imgs})

for images, row in zip([in_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

fig.tight_layout(pad=0.1)

# %%
sess.close()

# %% [markdown]
# ## Up Next
#
# We're dealing with images here, so we can (usually) get better performance using convolution layers. So, next we'll build a better autoencoder with convolutional layers.
#
# In practice, autoencoders aren't actually better at compression compared to typical methods like JPEGs and MP3s. But, they are being used for noise reduction, which you'll also build.
